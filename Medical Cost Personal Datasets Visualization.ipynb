# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %% [markdown]
# ### spliting dataset based on age

# %%
aged_ppl=df[df['age']>=60]
normal_age=df[df['age']<60]

# %% [markdown]
# #### Univariate categorical analysis

# %%
ax=sns.countplot(data=aged_ppl,x='sex',hue='smoker')
plt.title('Aged people insurance taken ratio with gender')
for bar in ax.containers:
    ax.bar_label(bar)

# %%
ax=sns.countplot(data=normal_age,x='sex',hue='smoker')
plt.title('Normal age people insurance taken ratio with gender')
for bar in ax.containers:
    ax.bar_label(bar)

# %%
ax=sns.countplot(data=df,x='region')
plt.title("Beneficiary's residential areawise distribution in the US")
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# #### Univariate numerical analysis

# %%
sns.histplot(data=df,x='age')
plt.title('Insurance taken ratio based on Age')
# Out:
# Text(0.5, 1.0, 'Insurance taken ratio based on Age')

# %%
sns.countplot(data=df,x='children')
plt.title('Number of children covered in insurance')
# Out:
# Text(0.5, 1.0, 'Number of children covered in insurance')

# %%
sns.histplot(data=df,x='bmi')
plt.title('Insurance taken ratio based on BMI')
# Out:
# Text(0.5, 1.0, 'Insurance taken ratio based on BMI')

# %% [markdown]
# #### Bivariate analysis

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=df,x='age',y='charges')
plt.title('Individual medical costs billed by insurance based on Age')
# Out:
# Text(0.5, 1.0, 'Individual medical costs billed by insurance based on Age')

# %%
plt.figure(figsize=(15,7))
sns.barplot(data=df,x='sex',y='age',hue='region')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ### Pie Chart

# %%
df['region'].value_counts().plot(kind='pie',autopct = "%0.2f%%")
plt.title("Beneficiary's residential areawise distribution in the US")
# Out:
# Text(0.5, 1.0, "Beneficiary's residential areawise distribution in the US")

# %%
df['children'].value_counts().plot(kind='pie',autopct = "%0.2f%%")
plt.title("Number of children covered in insurance")
# Out:
# Text(0.5, 1.0, 'Number of children covered in insurance')

# %%
df['sex'].value_counts().plot(kind='pie',autopct = "%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['smoker'].value_counts().plot(kind='pie',autopct = "%0.2f%%")
# Out:
# <Axes: ylabel='count'>
